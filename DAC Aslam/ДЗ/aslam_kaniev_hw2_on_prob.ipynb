# %%
import math

# %%
# Задача 1: Количество паролей длиной 5, где каждая цифра от 0 до 9
count_passwords = 10 ** 5
count_passwords
# Out:
# 100000

# %%
# Задача 2: Перестановки 7 книг
count_arrangements = math.factorial(7)
count_arrangements
# Out:
# 5040

# %%
# Задача 3: Количество линий между 9 точками
count_lines = math.comb(9, 2)
count_lines
# Out:
# 36

# %%
# Задача 4: Количество вариантов билетов между 19 станциями
stations = 19
count_tickets = stations * (stations - 1)
count_tickets
# Out:
# 342
