# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df ['Payment ID'].value_counts()
# Out:
# Payment ID
# Thur8084    2
# Sun4608     1
# Sun2959     1
# Sun5260     1
# Sun2251     1
#            ..
# Sat2657     1
# Sat1766     1
# Sat3880     1
# Sat17       1
# Thur672     1
# Name: count, Length: 243, dtype: int64

# %%
df['size'].value_counts()
# Out:
# size
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: count, dtype: int64

# %%
df ['id'] = df['Payment ID']

# %%
df.drop(columns=['Payment ID'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df.drop(columns=['Payment ID'], axis = 1)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)   5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)   5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
# ...

# %%
df.rename(columns={'CC Number': 'card_num', 'Payer Name': 'payer_name'}, inplace=True)

# %%
df['size'] = df['size'] - 1

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['card_num'] * 10
# Out:
# 0      35603251686034100
# 1      44780713797792300
# 2      60118121129713220
# 3      46761376476859940
# 4      48327326186372210
#              ...
# 239    52960686060528420
# 240    35068061555654040
# 241    60118916187471960
# 242       43752205509500
# 243    35114516266981390
# Name: card_num, Length: 244, dtype: int64

# %%
df['card_num'] % 10000
# Out:
# 0      3410
# 1      9230
# 2      1322
# 3      5994
# 4      7221
#        ...
# 239    2842
# 240    5404
# 241    7196
# 242     950
# 243    8139
# Name: card_num, Length: 244, dtype: int64

# %%
df['card_num'].astype('str')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              payer_name          card_num       id
# ...

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'payer_name', 'card_num', 'id'],
#       dtype='object')

# %%
df
# Out:
#    day  value
# 0  Mon      1
# 1  Tue      2
# 2  Sat      3
# 3  Sun      4
# 4  Fri      5

# %%
df[(df['size'] == 2) & (df['total_bill'] > 10)]
df[(df['day'] == 'Sun') | (df['day'] == 'Sat')]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
df['day'].value_counts()
# Out:
# day
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: count, dtype: int64

# %%
smokers = df[((df['day'] == 'Sat') | (df['day'] == 'Sun')) & (df['smoker'] == 'Yes')].shape[0]
print(smokers)
# Out:
# 61

# %%
total_bill = df['total_bill'].sum()
total_tips = df['tip'].sum()
restaurant_income_excl_tips = total_revenue - total_tips  # если чаевые идут официантам

print(f"Общая выручка (счета): {total_revenue:.2f}")
print(f"Общая сумма чаевых (доход официанта): {total_tips:.2f}")
print(f"Выручка ресторана без чаевых: {restaurant_income_excl_tips:.2f}")

# %%
df['total_bill'].sum()
# Out:
# np.float64(4827.77)

# %%
df['tip'].sum()
# Out:
# np.float64(731.5799999999999)

# %%
df.tail(50)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 194       16.58  4.00    Male    Yes  Thur   Lunch     2              8.29
# 195        7.56  1.44    Male     No  Thur   Lunch     2              3.78
# 196       10.34  2.00    Male    Yes  Thur   Lunch     2              5.17
# 197       43.11  5.00  Female    Yes  Thur   Lunch     4             10.78
# 198       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 199       13.51  2.00    Male    Yes  Thur   Lunch     2              6.76
# 200       18.71  4.00    Male    Yes  Thur   Lunch     3              6.24
# 201       12.74  2.01  Female    Yes  Thur   Lunch     2              6.37
# 202       13.00  2.00  Female    Yes  Thur   Lunch     2              6.50
# 203       16.40  2.50  Female    Yes  Thur   Lunch     2              8.20
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4              5.13
# ...

# %%
df['tip_percent'] = round(( df['total_bill'])  / 100 * df['tip'], 2)

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID  tip_percent
# ...

# %%
rows = 6

for i in range(rows):
    for j in range(rows -i -1):
        print(" ", end="")
    for j in range(2 * i + 1):
        print("*", end="")
    print()
# Out:
#      *
#     ***
#    *****
#   *******
#  *********
# ***********

# %%
def helloworld():
    helloworld = print
    helloworld("print")

# %%
helloworld()
# Out:
# print
